# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting snscrape
#   Downloading snscrape-0.3.4-py3-none-any.whl (35 kB)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from snscrape) (2.23.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.9.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2022.9.24)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.3.4

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
query = "chettiar until:2010-12-31 since:2010-01-01"
tweets = []
limit = 5000


for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])
        
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
print(df)

# to save to csv
df.to_csv('tweets_chettiar_2010_5000.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-624d545970b1> in <module>
#       4
#       5
# ----> 6 for tweet in sntwitter.TwitterSearchScraper(query).get_items():
#       7
#       8     # print(vars(tweet))
#
# NameError: name 'sntwitter' is not defined

# %%
df.head()
# Out:
#                        Date     User  \
# 0 2010-12-30 18:39:32+00:00  bandhan
# 1 2010-12-30 17:36:29+00:00  bandhan
# 2 2010-12-30 17:01:58+00:00  bandhan
# 3 2010-12-30 15:35:24+00:00  bandhan
# 4 2010-12-30 12:53:06+00:00  bandhan
#
#                                                Tweet
# 0  184 Matrimony profiles of Tamil Chettiar Tiruc...
# 1  Hindu, Chettiar, Beri Chettiar, Groom. 32 yrs,...
# 2  68 Matrimony profiles of Chettiar Malaysia  Gr...
# 3  54 Matrimony profiles of Tamil Chettiar Malays...
# 4  184 Matrimony profiles of Chettiar Tiruchirapp...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
txt = str(df)

# %%
type(txt)
# Out:
# str

# %%
len(txt)
# Out:
# 1333

# %%
import pandas as pd
import csv
from textblob import TextBlob
#from textblob.sentiments import NaiveBayesAnalyzers
##from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
import string
import nltk
#import textmining
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS
# set the working dierectory

# %%
# load the dataset
##post=pd.read_csv("Post.csv")
##post.head(20)

post = df
post.head(20)
# Out:
#                         Date             User  \
# 0  2010-12-30 18:39:32+00:00          bandhan
# 1  2010-12-30 17:36:29+00:00          bandhan
# 2  2010-12-30 17:01:58+00:00          bandhan
# 3  2010-12-30 15:35:24+00:00          bandhan
# 4  2010-12-30 12:53:06+00:00          bandhan
# 5  2010-12-30 00:12:09+00:00          bandhan
# 6  2010-12-29 18:29:01+00:00  flyspynederland
# 7  2010-12-29 18:29:00+00:00    russianews247
# 8  2010-12-29 15:04:23+00:00          bandhan
# 9  2010-12-29 11:37:22+00:00          bandhan
# 10 2010-12-29 11:30:33+00:00          cilaaaa
# 11 2010-12-29 10:30:19+00:00      wildescapes
# 12 2010-12-29 06:59:44+00:00          bandhan
# 13 2010-12-28 23:02:32+00:00          bandhan
# 14 2010-12-28 13:29:28+00:00          bandhan
# 15 2010-12-28 10:19:47+00:00          bandhan
# 16 2010-12-28 02:32:47+00:00          bandhan
# 17 2010-12-28 00:44:33+00:00          bandhan
# 18 2010-12-27 11:11:13+00:00          bandhan
# 19 2010-12-27 06:37:33+00:00      wildescapes
#
#                                                 Tweet
# 0   184 Matrimony profiles of Tamil Chettiar Tiruc...
# 1   Hindu, Chettiar, Beri Chettiar, Groom. 32 yrs,...
# 2   68 Matrimony profiles of Chettiar Malaysia  Gr...
# 3   54 Matrimony profiles of Tamil Chettiar Malays...
# 4   184 Matrimony profiles of Chettiar Tiruchirapp...
# 5   57 Matrimony profiles of Chettiar Pondicherry ...
# 6   #africa Chettiar’s funeral, UoM polls mark Sep...
# 7   Chettiar’s funeral, UoM polls mark Sept/Oct: S...
# 8   Hindu, Chettiar, Vaniya Chettiar, Groom. 28 yr...
# 9   104 Matrimony profiles of Tamil Chettiar Madur...
# 10  bukan kak,tp aku juga manggil nenek aku awwa h...
# 11  Vidhya Chettiar & Karan Gawdi could you please...
# 12  110 Matrimony profiles of Tamil Chettiar Tirun...
# 13  Hindu, Chettiar, 24 Manai Telugu Chettiar, Gro...
# 14  Hindu, Chettiar, Groom. 28 yrs, Masters - Comp...
# 15  Hindu, Chettiar, Kongu Chettiar, Groom. 26 yrs...
# 16  82 Matrimony profiles of Chettiar Namakkal  Gr...
# 17  Hindu, Chettiar, Beri Chettiar, Bride. 25 yrs,...
# 18  71 Matrimony profiles of Tamil Chettiar Mumbai...
# 19  Vidhya Chettiar - we have received the enrolme...

# %%
# select few text
post = post.iloc[:1000,]
post.shape
# Out:
# (1000, 3)

# %%
import nltk
nltk.download("popular")

# %%
# Importing necessary library
import pandas as pd
import numpy as np
import nltk
import os
import nltk.corpus
# sample text for performing tokenization
#text = "In Brazil they drive on the right-hand side of the road. Brazil has a large coastline on the eastern side of South America"
text = str(df["Tweet"])
# importing word_tokenize from nltk
from nltk.tokenize import word_tokenize
# Passing the string text into word tokenize for breaking the sentences
token = word_tokenize(text)
#token

# %%
text
# Out:
# '0       184 Matrimony profiles of Tamil Chettiar Tiruc...\n1       Hindu, Chettiar, Beri Chettiar, Groom. 32 yrs,...\n2       68 Matrimony profiles of Chettiar Malaysia  Gr...\n3       54 Matrimony profiles of Tamil Chettiar Malays...\n4       184 Matrimony profiles of Chettiar Tiruchirapp...\n                              ...                        \n1490    @Alamsha_Karnan @drssdutt Poonul is only an id...\n1491    Star Phoenix wins Alagappa Chettiar cup http:/...\n1492    Star Phoenix appeals most CHENNAI: Star Phoeni...\n1493    Hindu, Chettiar, Berichettiar, Groom. 28 yrs, ...\n1494    Hindu, Chettiar, Bari Chettiar, Groom. 28 yrs,...\nName: Tweet, Length: 1495, dtype: object'

# %%
token[1]
# Out:
# '184'

# %%
token

# %%
# finding the frequency distinct in the tokens
# Importing FreqDist library from nltk and passing token into FreqDist
from nltk.probability import FreqDist
fdist = FreqDist(token)
fdist
# Out:
# FreqDist({',': 14, '...': 11, 'Chettiar': 10, ':': 5, 'Matrimony': 4, 'profiles': 4, 'of': 4, 'Hindu': 3, 'Groom': 3, '.': 3, ...})

# %%
# To find the frequency of top 10 words
fdist1 = fdist.most_common(10)
fdist1
# Out:
# [(',', 14),
#  ('...', 11),
#  ('Chettiar', 10),
#  (':', 5),
#  ('Matrimony', 4),
#  ('profiles', 4),
#  ('of', 4),
#  ('Hindu', 3),
#  ('Groom', 3),
#  ('.', 3)]

# %% [markdown]
# #Stemming

# %%
# Importing Porterstemmer from nltk library
# Checking for the word ‘giving’ 
from nltk.stem import PorterStemmer
pst = PorterStemmer()
pst.stem("profiles")
# Out:
# 'profil'

# %%
# Checking for the list of words
stm = ["waited", "waiting", "waits"]
for word in stm :
   print(word+ ":" +pst.stem(word))
# Out:
# waited:wait
# waiting:wait
# waits:wait

# %% [markdown]
# #Lemmatisation

# %%
# Importing Lemmatizer library from nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer() 
 
print(“rocks :”, lemmatizer.lemmatize(“rocks”)) 
print(“corpora :”, lemmatizer.lemmatize(“corpora”))

# %%
# finding the frequency distinct in the tokens
# Importing FreqDist library from nltk and passing token into FreqDist
from nltk.probability import FreqDist
fdist = FreqDist(token)
fdist
# Out:
# FreqDist({',': 14, '...': 11, 'Chettiar': 10, ':': 5, 'Matrimony': 4, 'profiles': 4, 'of': 4, 'Hindu': 3, 'Groom': 3, '.': 3, ...})

# %%
# define the stopwords and also import predefined ones
stop=set(stopwords.words("english"))
# Extract punctuation marks
punct_exclude=set(string.punctuation)
